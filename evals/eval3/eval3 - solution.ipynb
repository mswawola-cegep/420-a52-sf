# %% [markdown]
# # Evaluation formative #3 - Solutions

# %% [markdown]
# Utiliser ce notebook et répondre aux questions du formulaire
# * [https://forms.gle/ty6EQ9VCoF1YhJNEA](https://forms.gle/ty6EQ9VCoF1YhJNEA)
# * Durée: 40 minutes

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### 1 - Simulation de données

# %%
from sklearn.datasets import make_circles

# %%
N = 100
X, y = make_circles(n_samples=10*N, shuffle=True, noise=0.1, random_state=2021)

# %% [markdown]
# #### Affichage du jeu de données simulé

# %%
import matplotlib.pyplot as plt

fig = plt.figure(1, figsize=(12, 9))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='PiYG', edgecolor='k', s=30)
plt.show()

# %% [markdown]
# ### 2 - Préparation de données

# %% [markdown]
# <strong>
# Séparation des données en train et validation
# </strong>

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=0.6, random_state=2021)

# %%
import numpy as np

print('Classe négative')
print(f'Train {len(y_train) - np.sum(y_train)}') 
print(f'Val {len(y_val) - np.sum(y_val)}')

print('\nClasse positive')
print(f'Train {np.sum(y_train)}') 
print(f'Val {np.sum(y_val)}')
# Out:
# Classe négative
# Train 306
# Val 194
#
# Classe positive
# Train 294
# Val 206

# %%
X_val.shape
# Out:
# (400, 2)

# %% [markdown]
# ### 3 - Modèle de référence (baseline)

# %%
from sklearn.dummy import DummyClassifier

baseline_clf = DummyClassifier(strategy='most_frequent') 
baseline_clf.fit(X_train, y_train)
# Out:
# DummyClassifier(strategy='most_frequent')

# %%
acc_baseline = baseline_clf.score(X_train, y_train)
print(f'Performance du modèle de référence (dummy): {100*acc_baseline}%')
# Out:
# Performance du modèle de référence (dummy): 51.0%

# %% [markdown]
# ### 4 - Régression logistique, ordre 1

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(penalty='l1', C=0.1, solver="saga", random_state=2021).fit(X_train, y_train)
logreg.score(X_train,y_train)
# Out:
# 0.51

# %%
logreg.score(X_val,y_val)
# Out:
# 0.485

# %% [markdown]
# ### Fin du Quiz
